# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 769

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+") + "&APPID=" + weather_api_key
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
           
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description" : city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao filipe
# Processing Record 2 of Set 1 | rocha
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | lodwar
# Processing Record 8 of Set 1 | kirakira
# Processing Record 9 of Set 1 | wilmington
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 1 | asau
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | lata
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | shadrinsk
# Processing Record 19 of Set 1 | del rio
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | verkh-usugli
# Processing Record 23 of Set 1 | sinnamary
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | zhuozhou
# City not found. Skipping...
# Processing Record 26 of Set 1 | ambon
# Processing Record 27 of Set 1 | jasidih
# Processing Record 28 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | praia da vitoria
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 1 | kavaratti
# Processing Record 38 of Set 1 | puerto madryn
# Processing Record 39 of Set 1 | necochea
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | roebourne
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | batsfjord
# Processing Record 47 of Set 1 | dunedin
# Processing Record 48 of Set 1 | beringovskiy
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | sinop
# Processing Record 1 of Set 2 | nola
# Processing Record 2 of Set 2 | henties bay
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | olafsvik
# Processing Record 7 of Set 2 | nome
# Processing Record 8 of Set 2 | bubaque
# Processing Record 9 of Set 2 | hamilton
# Processing Record 10 of Set 2 | nuuk
# Processing Record 11 of Set 2 | constitucion
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | falavarjan
# Processing Record 14 of Set 2 | jacqueville
# Processing Record 15 of Set 2 | yanam
# Processing Record 16 of Set 2 | upata
# Processing Record 17 of Set 2 | tomatlan
# Processing Record 18 of Set 2 | buraydah
# Processing Record 19 of Set 2 | seoul
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | rosetta
# Processing Record 22 of Set 2 | muhos
# Processing Record 23 of Set 2 | alenquer
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | bengkalis
# City not found. Skipping...
# Processing Record 28 of Set 2 | kathmandu
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | mount gambier
# Processing Record 31 of Set 2 | oranjemund
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | nhulunbuy
# Processing Record 34 of Set 2 | shimoda
# Processing Record 35 of Set 2 | grindavik
# Processing Record 36 of Set 2 | whitehorse
# Processing Record 37 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | hokitika
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | laguna
# Processing Record 41 of Set 2 | lagos
# Processing Record 42 of Set 2 | velez-malaga
# Processing Record 43 of Set 2 | nimes
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | husavik
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | nalut
# Processing Record 50 of Set 2 | rochegda
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | gainesville
# Processing Record 4 of Set 3 | aklavik
# Processing Record 5 of Set 3 | mizan teferi
# Processing Record 6 of Set 3 | new norfolk
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | adre
# Processing Record 9 of Set 3 | harnosand
# Processing Record 10 of Set 3 | portland
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | cuamba
# Processing Record 13 of Set 3 | tautira
# Processing Record 14 of Set 3 | marseille
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | inta
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | lorengau
# Processing Record 19 of Set 3 | cabedelo
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | payakumbuh
# Processing Record 22 of Set 3 | gilbues
# Processing Record 23 of Set 3 | butaritari
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | poum
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | filingue
# Processing Record 28 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 3 | ubeda
# Processing Record 30 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 3 | kourou
# Processing Record 32 of Set 3 | dakar
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | mutsu
# Processing Record 35 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | port macquarie
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 3 | mnogovershinnyy
# Processing Record 41 of Set 3 | bulawayo
# Processing Record 42 of Set 3 | madang
# Processing Record 43 of Set 3 | jasper
# Processing Record 44 of Set 3 | nanortalik
# Processing Record 45 of Set 3 | kulhudhuffushi
# Processing Record 46 of Set 3 | aswan
# Processing Record 47 of Set 3 | coquimbo
# Processing Record 48 of Set 3 | natal
# Processing Record 49 of Set 3 | tual
# Processing Record 50 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 1 of Set 4 | half moon bay
# Processing Record 2 of Set 4 | mitsamiouli
# Processing Record 3 of Set 4 | scarborough
# Processing Record 4 of Set 4 | morehead
# Processing Record 5 of Set 4 | takoradi
# Processing Record 6 of Set 4 | urumqi
# Processing Record 7 of Set 4 | viksoyri
# City not found. Skipping...
# Processing Record 8 of Set 4 | port augusta
# Processing Record 9 of Set 4 | romny
# Processing Record 10 of Set 4 | guntakal
# Processing Record 11 of Set 4 | flinders
# Processing Record 12 of Set 4 | haines junction
# Processing Record 13 of Set 4 | geraldton
# Processing Record 14 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 4 | saint-georges
# Processing Record 16 of Set 4 | karwar
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | lahaina
# Processing Record 19 of Set 4 | awash
# Processing Record 20 of Set 4 | waipawa
# Processing Record 21 of Set 4 | arraial do cabo
# Processing Record 22 of Set 4 | bandar
# Processing Record 23 of Set 4 | linxia
# Processing Record 24 of Set 4 | severo-kurilsk
# Processing Record 25 of Set 4 | muros
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | mount isa
# Processing Record 28 of Set 4 | duki
# Processing Record 29 of Set 4 | posse
# Processing Record 30 of Set 4 | richards bay
# Processing Record 31 of Set 4 | shwebo
# Processing Record 32 of Set 4 | naze
# Processing Record 33 of Set 4 | nelson bay
# Processing Record 34 of Set 4 | nguruka
# Processing Record 35 of Set 4 | wanning
# Processing Record 36 of Set 4 | nouadhibou
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | nantucket
# Processing Record 39 of Set 4 | san andres
# Processing Record 40 of Set 4 | ternate
# Processing Record 41 of Set 4 | bredasdorp
# Processing Record 42 of Set 4 | inca
# Processing Record 43 of Set 4 | tuktoyaktuk
# Processing Record 44 of Set 4 | charqueada
# Processing Record 45 of Set 4 | los llanos de aridane
# Processing Record 46 of Set 4 | bathsheba
# Processing Record 47 of Set 4 | stoughton
# Processing Record 48 of Set 4 | kamen-na-obi
# Processing Record 49 of Set 4 | andros town
# Processing Record 50 of Set 4 | pangkalanbuun
# Processing Record 1 of Set 5 | lompoc
# Processing Record 2 of Set 5 | eyl
# Processing Record 3 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 5 | hoquiam
# Processing Record 5 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 5 | dawei
# Processing Record 7 of Set 5 | bonavista
# Processing Record 8 of Set 5 | lebu
# Processing Record 9 of Set 5 | tasiilaq
# Processing Record 10 of Set 5 | tecolutilla
# Processing Record 11 of Set 5 | santa maria da boa vista
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | millinocket
# Processing Record 14 of Set 5 | topolobampo
# Processing Record 15 of Set 5 | puerto ayora
# Processing Record 16 of Set 5 | torbay
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | ust-tsilma
# Processing Record 19 of Set 5 | emba
# Processing Record 20 of Set 5 | brae
# Processing Record 21 of Set 5 | maceio
# Processing Record 22 of Set 5 | zyryanka
# Processing Record 23 of Set 5 | kreminna
# Processing Record 24 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 25 of Set 5 | gambo
# Processing Record 26 of Set 5 | shu
# Processing Record 27 of Set 5 | abeche
# Processing Record 28 of Set 5 | tirano
# Processing Record 29 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 5 | kavieng
# Processing Record 33 of Set 5 | babstovo
# Processing Record 34 of Set 5 | salmo
# Processing Record 35 of Set 5 | hebi
# Processing Record 36 of Set 5 | shimanovsk
# Processing Record 37 of Set 5 | pecos
# Processing Record 38 of Set 5 | skelleftea
# Processing Record 39 of Set 5 | shahapur
# Processing Record 40 of Set 5 | newport
# Processing Record 41 of Set 5 | chapais
# Processing Record 42 of Set 5 | victoria
# Processing Record 43 of Set 5 | baracoa
# Processing Record 44 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 5 | gat
# Processing Record 46 of Set 5 | pitimbu
# Processing Record 47 of Set 5 | narsaq
# Processing Record 48 of Set 5 | shenxian
# Processing Record 49 of Set 5 | dongying
# Processing Record 50 of Set 5 | ourossogui
# Processing Record 1 of Set 6 | oriximina
# Processing Record 2 of Set 6 | saint andrews
# Processing Record 3 of Set 6 | jalu
# Processing Record 4 of Set 6 | leningradskiy
# Processing Record 5 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 6 | hofn
# Processing Record 7 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 6 | vaini
# Processing Record 9 of Set 6 | banda aceh
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | saint george
# Processing Record 12 of Set 6 | bequimao
# Processing Record 13 of Set 6 | talesh
# City not found. Skipping...
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | terrace bay
# Processing Record 16 of Set 6 | inhambane
# Processing Record 17 of Set 6 | nemours
# Processing Record 18 of Set 6 | tagusao
# Processing Record 19 of Set 6 | bairiki
# Processing Record 20 of Set 6 | nunkini
# Processing Record 21 of Set 6 | qaqortoq
# Processing Record 22 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 6 | pochutla
# Processing Record 24 of Set 6 | talgar
# Processing Record 25 of Set 6 | hualmay
# Processing Record 26 of Set 6 | kenai
# Processing Record 27 of Set 6 | iqaluit
# Processing Record 28 of Set 6 | bambous virieux
# Processing Record 29 of Set 6 | puerto del rosario
# Processing Record 30 of Set 6 | knysna
# Processing Record 31 of Set 6 | labuan
# Processing Record 32 of Set 6 | ancud
# Processing Record 33 of Set 6 | merauke
# Processing Record 34 of Set 6 | strezhevoy
# Processing Record 35 of Set 6 | maryborough
# Processing Record 36 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 6 | lecce
# Processing Record 38 of Set 6 | bandarbeyla
# Processing Record 39 of Set 6 | kaduqli
# Processing Record 40 of Set 6 | mehamn
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | kungurtug
# Processing Record 43 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 6 | santa maria
# Processing Record 45 of Set 6 | college
# Processing Record 46 of Set 6 | saint-pierre
# Processing Record 47 of Set 6 | roma
# Processing Record 48 of Set 6 | clyde river
# Processing Record 49 of Set 6 | san patricio
# Processing Record 50 of Set 6 | ryotsu
# Processing Record 1 of Set 7 | mar del plata
# Processing Record 2 of Set 7 | taoudenni
# Processing Record 3 of Set 7 | shintomi
# Processing Record 4 of Set 7 | jizan
# Processing Record 5 of Set 7 | kisangani
# Processing Record 6 of Set 7 | chopda
# Processing Record 7 of Set 7 | tabou
# Processing Record 8 of Set 7 | tigil
# Processing Record 9 of Set 7 | maltahohe
# Processing Record 10 of Set 7 | socorro
# Processing Record 11 of Set 7 | komsomolskiy
# Processing Record 12 of Set 7 | ayan
# Processing Record 13 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 14 of Set 7 | brive-la-gaillarde
# Processing Record 15 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 7 | tottori
# Processing Record 17 of Set 7 | ambilobe
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | sistranda
# Processing Record 20 of Set 7 | hambantota
# Processing Record 21 of Set 7 | ishim
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | kahului
# Processing Record 24 of Set 7 | vilyuysk
# Processing Record 25 of Set 7 | caravelas
# Processing Record 26 of Set 7 | shaowu
# Processing Record 27 of Set 7 | hobyo
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | gewane
# Processing Record 30 of Set 7 | urucui
# Processing Record 31 of Set 7 | arlit
# Processing Record 32 of Set 7 | shenkursk
# Processing Record 33 of Set 7 | zhezkazgan
# Processing Record 34 of Set 7 | carutapera
# Processing Record 35 of Set 7 | ust-kuyga
# Processing Record 36 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 7 | bethanien
# Processing Record 38 of Set 7 | cozumel
# Processing Record 39 of Set 7 | mahanje
# Processing Record 40 of Set 7 | lagoa
# Processing Record 41 of Set 7 | loa janan
# Processing Record 42 of Set 7 | biograd na moru
# Processing Record 43 of Set 7 | lavrentiya
# Processing Record 44 of Set 7 | steamboat springs
# Processing Record 45 of Set 7 | telimele
# Processing Record 46 of Set 7 | mtambile
# Processing Record 47 of Set 7 | bikaner
# Processing Record 48 of Set 7 | malnas
# Processing Record 49 of Set 7 | cody
# Processing Record 50 of Set 7 | camacha
# Processing Record 1 of Set 8 | labuhan
# Processing Record 2 of Set 8 | conceicao da barra
# Processing Record 3 of Set 8 | barcelos
# Processing Record 4 of Set 8 | xinyu
# Processing Record 5 of Set 8 | iskateley
# Processing Record 6 of Set 8 | souillac
# Processing Record 7 of Set 8 | san quintin
# Processing Record 8 of Set 8 | quelimane
# Processing Record 9 of Set 8 | werda
# Processing Record 10 of Set 8 | sechura
# Processing Record 11 of Set 8 | ilawe
# Processing Record 12 of Set 8 | novikovo
# Processing Record 13 of Set 8 | senador guiomard
# Processing Record 14 of Set 8 | ayacucho
# Processing Record 15 of Set 8 | gazni
# City not found. Skipping...
# Processing Record 16 of Set 8 | le port
# Processing Record 17 of Set 8 | luganville
# Processing Record 18 of Set 8 | brewster
# Processing Record 19 of Set 8 | totma
# Processing Record 20 of Set 8 | hakkari
# Processing Record 21 of Set 8 | marystown
# Processing Record 22 of Set 8 | liverpool
# Processing Record 23 of Set 8 | ambulu
# Processing Record 24 of Set 8 | alice springs
# Processing Record 25 of Set 8 | maracaibo
# Processing Record 26 of Set 8 | suntar
# Processing Record 27 of Set 8 | beian
# Processing Record 28 of Set 8 | bud
# Processing Record 29 of Set 8 | singkawang
# Processing Record 30 of Set 8 | agaro
# Processing Record 31 of Set 8 | noumea
# Processing Record 32 of Set 8 | shenzhen
# Processing Record 33 of Set 8 | bilibino
# Processing Record 34 of Set 8 | vigrestad
# Processing Record 35 of Set 8 | ormara
# Processing Record 36 of Set 8 | vila franca do campo
# Processing Record 37 of Set 8 | puerto cabezas
# Processing Record 38 of Set 8 | santa cruz
# Processing Record 39 of Set 8 | oussouye
# Processing Record 40 of Set 8 | port hardy
# Processing Record 41 of Set 8 | san angelo
# Processing Record 42 of Set 8 | salinas
# Processing Record 43 of Set 8 | aranos
# Processing Record 44 of Set 8 | bac lieu
# Processing Record 45 of Set 8 | fare
# Processing Record 46 of Set 8 | pamplonita
# Processing Record 47 of Set 8 | rafai
# Processing Record 48 of Set 8 | kruisfontein
# Processing Record 49 of Set 8 | guerrero negro
# Processing Record 50 of Set 8 | carbonia
# Processing Record 1 of Set 9 | gamba
# Processing Record 2 of Set 9 | burgeo
# Processing Record 3 of Set 9 | batan
# Processing Record 4 of Set 9 | aguimes
# Processing Record 5 of Set 9 | avera
# Processing Record 6 of Set 9 | magistralnyy
# Processing Record 7 of Set 9 | kawalu
# Processing Record 8 of Set 9 | cap malheureux
# Processing Record 9 of Set 9 | khani
# Processing Record 10 of Set 9 | sisimiut
# Processing Record 11 of Set 9 | douentza
# Processing Record 12 of Set 9 | paso de carrasco
# Processing Record 13 of Set 9 | vostok
# Processing Record 14 of Set 9 | berlevag
# Processing Record 15 of Set 9 | namatanai
# Processing Record 16 of Set 9 | nizwa
# Processing Record 17 of Set 9 | walvis bay
# Processing Record 18 of Set 9 | tevaitoa
# Processing Record 19 of Set 9 | cabra
# Processing Record 20 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 21 of Set 9 | brigantine
# Processing Record 22 of Set 9 | talcahuano
# Processing Record 23 of Set 9 | lieksa
# Processing Record 24 of Set 9 | camana
# Processing Record 25 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 9 | luanda
# Processing Record 27 of Set 9 | nampula
# Processing Record 28 of Set 9 | fairbanks
# Processing Record 29 of Set 9 | eenhana
# Processing Record 30 of Set 9 | atherton
# Processing Record 31 of Set 9 | yabelo
# Processing Record 32 of Set 9 | neyyattinkara
# Processing Record 33 of Set 9 | barranca
# Processing Record 34 of Set 9 | tupiza
# Processing Record 35 of Set 9 | kudahuvadhoo
# Processing Record 36 of Set 9 | fort nelson
# Processing Record 37 of Set 9 | yerbogachen
# Processing Record 38 of Set 9 | rorvik
# Processing Record 39 of Set 9 | ornskoldsvik
# Processing Record 40 of Set 9 | tera
# Processing Record 41 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 9 | griffith
# Processing Record 43 of Set 9 | pangody
# Processing Record 44 of Set 9 | sarkand
# Processing Record 45 of Set 9 | pevek
# Processing Record 46 of Set 9 | zhangye
# Processing Record 47 of Set 9 | yeysk
# Processing Record 48 of Set 9 | kursk
# Processing Record 49 of Set 9 | ahipara
# Processing Record 50 of Set 9 | jvari
# Processing Record 1 of Set 10 | davila
# Processing Record 2 of Set 10 | vidim
# Processing Record 3 of Set 10 | kalevala
# Processing Record 4 of Set 10 | berdsk
# Processing Record 5 of Set 10 | marienburg
# Processing Record 6 of Set 10 | sao joao da barra
# Processing Record 7 of Set 10 | touros
# Processing Record 8 of Set 10 | jaisinghnagar
# Processing Record 9 of Set 10 | ilulissat
# Processing Record 10 of Set 10 | cintalapa
# Processing Record 11 of Set 10 | yulara
# Processing Record 12 of Set 10 | ghanzi
# Processing Record 13 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 10 | tarakan
# Processing Record 15 of Set 10 | hammerfest
# Processing Record 16 of Set 10 | vestmannaeyjar
# Processing Record 17 of Set 10 | warrnambool
# Processing Record 18 of Set 10 | itoman
# Processing Record 19 of Set 10 | valley station
# Processing Record 20 of Set 10 | skjervoy
# Processing Record 21 of Set 10 | moerai
# Processing Record 22 of Set 10 | bobon
# Processing Record 23 of Set 10 | kysyl-syr
# Processing Record 24 of Set 10 | chaochou
# City not found. Skipping...
# Processing Record 25 of Set 10 | aykhal
# Processing Record 26 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 10 | tilichiki
# Processing Record 28 of Set 10 | amahai
# Processing Record 29 of Set 10 | baykalovo
# Processing Record 30 of Set 10 | port hedland
# Processing Record 31 of Set 10 | muskegon
# Processing Record 32 of Set 10 | mayo
# Processing Record 33 of Set 10 | roseburg
# Processing Record 34 of Set 10 | usinsk
# Processing Record 35 of Set 10 | presevo
# Processing Record 36 of Set 10 | dubbo
# Processing Record 37 of Set 10 | basco
# Processing Record 38 of Set 10 | katsuura
# Processing Record 39 of Set 10 | platanos
# Processing Record 40 of Set 10 | auchi
# Processing Record 41 of Set 10 | gueret
# Processing Record 42 of Set 10 | paragominas
# Processing Record 43 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 10 | khomeynishahr
# City not found. Skipping...
# Processing Record 45 of Set 10 | tombouctou
# Processing Record 46 of Set 10 | sur
# Processing Record 47 of Set 10 | krasnovishersk
# Processing Record 48 of Set 10 | copiapo
# Processing Record 49 of Set 10 | tiarei
# Processing Record 50 of Set 10 | kununurra
# Processing Record 1 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 11 | turukhansk
# Processing Record 3 of Set 11 | maple creek
# Processing Record 4 of Set 11 | smithers
# Processing Record 5 of Set 11 | montelibano
# Processing Record 6 of Set 11 | ao luk
# City not found. Skipping...
# Processing Record 7 of Set 11 | flin flon
# Processing Record 8 of Set 11 | governador valadares
# Processing Record 9 of Set 11 | belyy yar
# Processing Record 10 of Set 11 | singaraja
# Processing Record 11 of Set 11 | presidente olegario
# Processing Record 12 of Set 11 | launceston
# Processing Record 13 of Set 11 | vitim
# Processing Record 14 of Set 11 | honiara
# Processing Record 15 of Set 11 | tiznit
# Processing Record 16 of Set 11 | svetlaya
# Processing Record 17 of Set 11 | delta del tigre
# Processing Record 18 of Set 11 | salamiyah
# Processing Record 19 of Set 11 | fuyang
# Processing Record 20 of Set 11 | sibu
# Processing Record 21 of Set 11 | nisia floresta
# Processing Record 22 of Set 11 | stepnoye
# Processing Record 23 of Set 11 | bongor
# Processing Record 24 of Set 11 | clonakilty
# Processing Record 25 of Set 11 | marsa matruh
# Processing Record 26 of Set 11 | shubarshi
# Processing Record 27 of Set 11 | martapura
# Processing Record 28 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 11 | talaya
# Processing Record 30 of Set 11 | klang
# Processing Record 31 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 11 | puruaran
# Processing Record 33 of Set 11 | hasaki
# Processing Record 34 of Set 11 | khilok
# Processing Record 35 of Set 11 | lujan
# Processing Record 36 of Set 11 | singaparna
# Processing Record 37 of Set 11 | rio grande
# Processing Record 38 of Set 11 | boguchany
# Processing Record 39 of Set 11 | tornio
# Processing Record 40 of Set 11 | etaples
# Processing Record 41 of Set 11 | pangnirtung
# Processing Record 42 of Set 11 | dingle
# Processing Record 43 of Set 11 | trapani
# Processing Record 44 of Set 11 | okhotsk
# Processing Record 45 of Set 11 | sidrolandia
# Processing Record 46 of Set 11 | evensk
# Processing Record 47 of Set 11 | nemuro
# Processing Record 48 of Set 11 | souris
# Processing Record 49 of Set 11 | karratha
# Processing Record 50 of Set 11 | atar
# Processing Record 1 of Set 12 | senica
# Processing Record 2 of Set 12 | palora
# Processing Record 3 of Set 12 | saint-paul
# Processing Record 4 of Set 12 | debno
# Processing Record 5 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 6 of Set 12 | ivanovka
# Processing Record 7 of Set 12 | belmonte
# Processing Record 8 of Set 12 | quatre cocos
# Processing Record 9 of Set 12 | lindi
# Processing Record 10 of Set 12 | huazolotitlan
# City not found. Skipping...
# Processing Record 11 of Set 12 | ongandjera
# Processing Record 12 of Set 12 | tura
# Processing Record 13 of Set 12 | alyangula
# Processing Record 14 of Set 12 | bengkulu
# Processing Record 15 of Set 12 | araouane
# Processing Record 16 of Set 12 | springdale
# Processing Record 17 of Set 12 | ugoofaaru
# Processing Record 18 of Set 12 | beloha
# Processing Record 19 of Set 12 | coalcoman
# City not found. Skipping...
# Processing Record 20 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 12 | san policarpo
# Processing Record 22 of Set 12 | ostrovnoy
# Processing Record 23 of Set 12 | hami
# Processing Record 24 of Set 12 | tabuk
# Processing Record 25 of Set 12 | amazar
# Processing Record 26 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 12 | ponta delgada
# Processing Record 28 of Set 12 | san cristobal
# Processing Record 29 of Set 12 | kaitangata
# Processing Record 30 of Set 12 | the valley
# Processing Record 31 of Set 12 | dharchula
# Processing Record 32 of Set 12 | deputatskiy
# Processing Record 33 of Set 12 | peniche
# Processing Record 34 of Set 12 | high level
# Processing Record 35 of Set 12 | flagstaff
# Processing Record 36 of Set 12 | port blair
# Processing Record 37 of Set 12 | ianca
# Processing Record 38 of Set 12 | bahia blanca
# Processing Record 39 of Set 12 | robat karim
# Processing Record 40 of Set 12 | tawau
# Processing Record 41 of Set 12 | samarai
# Processing Record 42 of Set 12 | saldanha
# Processing Record 43 of Set 12 | biak
# Processing Record 44 of Set 12 | san juan
# Processing Record 45 of Set 12 | rajauri
# Processing Record 46 of Set 12 | mookane
# Processing Record 47 of Set 12 | turbat
# Processing Record 48 of Set 12 | san pedro
# Processing Record 49 of Set 12 | havre-saint-pierre
# Processing Record 50 of Set 12 | sambava
# Processing Record 1 of Set 13 | vila velha
# Processing Record 2 of Set 13 | puerto escondido
# Processing Record 3 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 13 | parapotamos
# Processing Record 5 of Set 13 | tome-acu
# City not found. Skipping...
# Processing Record 6 of Set 13 | siilinjarvi
# Processing Record 7 of Set 13 | codrington
# Processing Record 8 of Set 13 | maniitsoq
# Processing Record 9 of Set 13 | miracema do tocantins
# Processing Record 10 of Set 13 | vestmanna
# Processing Record 11 of Set 13 | obidos
# Processing Record 12 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 13 | leh
# Processing Record 14 of Set 13 | sobolevo
# Processing Record 15 of Set 13 | bahir dar
# Processing Record 16 of Set 13 | vuktyl
# Processing Record 17 of Set 13 | cartagena del chaira
# Processing Record 18 of Set 13 | mezen
# Processing Record 19 of Set 13 | dalvik
# Processing Record 20 of Set 13 | buriti dos lopes
# Processing Record 21 of Set 13 | dogondoutchi
# Processing Record 22 of Set 13 | teya
# Processing Record 23 of Set 13 | lazaro cardenas
# Processing Record 24 of Set 13 | vardo
# Processing Record 25 of Set 13 | westport
# Processing Record 26 of Set 13 | faxinal
# Processing Record 27 of Set 13 | mahajanga
# Processing Record 28 of Set 13 | gejiu
# Processing Record 29 of Set 13 | gisborne
# Processing Record 30 of Set 13 | chuy
# Processing Record 31 of Set 13 | vryburg
# Processing Record 32 of Set 13 | bacoor
# Processing Record 33 of Set 13 | wanaka
# Processing Record 34 of Set 13 | kamina
# Processing Record 35 of Set 13 | paita
# Processing Record 36 of Set 13 | ulaanbaatar
# Processing Record 37 of Set 13 | verkhoyansk
# Processing Record 38 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 39 of Set 13 | makakilo city
# Processing Record 40 of Set 13 | santa barbara
# Processing Record 41 of Set 13 | caceres
# Processing Record 42 of Set 13 | barstow
# Processing Record 43 of Set 13 | kalmunai
# Processing Record 44 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 45 of Set 13 | southbridge
# Processing Record 46 of Set 13 | kpandae
# Processing Record 47 of Set 13 | dosso
# Processing Record 48 of Set 13 | muroto
# Processing Record 49 of Set 13 | chany
# Processing Record 50 of Set 13 | hay river
# Processing Record 1 of Set 14 | ejido hermosillo
# Processing Record 2 of Set 14 | kokopo
# Processing Record 3 of Set 14 | itaituba
# Processing Record 4 of Set 14 | sesori
# Processing Record 5 of Set 14 | cayenne
# Processing Record 6 of Set 14 | gweta
# Processing Record 7 of Set 14 | te anau
# Processing Record 8 of Set 14 | torit
# Processing Record 9 of Set 14 | vanimo
# Processing Record 10 of Set 14 | necocli
# Processing Record 11 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 14 | boende
# Processing Record 13 of Set 14 | gubkinskiy
# Processing Record 14 of Set 14 | mbuji-mayi
# Processing Record 15 of Set 14 | raglan
# Processing Record 16 of Set 14 | saint-honore
# Processing Record 17 of Set 14 | dulce nombre de culmi
# Processing Record 18 of Set 14 | jackson
# Processing Record 19 of Set 14 | channel-port aux basques
# Processing Record 20 of Set 14 | staryy nadym
# Processing Record 21 of Set 14 | dom pedrito
# Processing Record 22 of Set 14 | maragogi
# Processing Record 23 of Set 14 | yatou
# Processing Record 24 of Set 14 | kurchum
# Processing Record 25 of Set 14 | ca mau
# Processing Record 26 of Set 14 | manggar
# Processing Record 27 of Set 14 | thaba-tseka
# Processing Record 28 of Set 14 | gravdal
# Processing Record 29 of Set 14 | tiksi
# Processing Record 30 of Set 14 | waitati
# Processing Record 31 of Set 14 | samana
# Processing Record 32 of Set 14 | tessalit
# Processing Record 33 of Set 14 | faridabad
# Processing Record 34 of Set 14 | arkhipo-osipovka
# Processing Record 35 of Set 14 | tondon
# Processing Record 36 of Set 14 | visnes
# Processing Record 37 of Set 14 | salekhard
# Processing Record 38 of Set 14 | zhob
# Processing Record 39 of Set 14 | koshurnikovo
# Processing Record 40 of Set 14 | talnakh
# Processing Record 41 of Set 14 | coihaique
# Processing Record 42 of Set 14 | agvali
# Processing Record 43 of Set 14 | liku
# Processing Record 44 of Set 14 | svetlogorsk
# Processing Record 45 of Set 14 | catuday
# Processing Record 46 of Set 14 | vilhena
# Processing Record 47 of Set 14 | wielun
# Processing Record 48 of Set 14 | yarke pole
# Processing Record 49 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 50 of Set 14 | umm lajj
# Processing Record 1 of Set 15 | naliya
# Processing Record 2 of Set 15 | kang
# Processing Record 3 of Set 15 | porto novo
# Processing Record 4 of Set 15 | abu samrah
# Processing Record 5 of Set 15 | healdsburg
# Processing Record 6 of Set 15 | luis correia
# Processing Record 7 of Set 15 | tonj
# Processing Record 8 of Set 15 | manzini
# Processing Record 9 of Set 15 | fallon
# Processing Record 10 of Set 15 | sakura
# Processing Record 11 of Set 15 | synya
# Processing Record 12 of Set 15 | tari
# Processing Record 13 of Set 15 | santo antonio do ica
# Processing Record 14 of Set 15 | kutum
# Processing Record 15 of Set 15 | khandbari
# Processing Record 16 of Set 15 | la sarre
# Processing Record 17 of Set 15 | ballina
# Processing Record 18 of Set 15 | japura
# Processing Record 19 of Set 15 | halifax
# Processing Record 20 of Set 15 | hailey
# Processing Record 21 of Set 15 | udachnyy
# Processing Record 22 of Set 15 | victor harbor
# Processing Record 23 of Set 15 | egvekinot
# Processing Record 24 of Set 15 | meulaboh
# Processing Record 25 of Set 15 | lincoln
# Processing Record 26 of Set 15 | danvers
# Processing Record 27 of Set 15 | mogok
# Processing Record 28 of Set 15 | huntington
# Processing Record 29 of Set 15 | bushehr
# Processing Record 30 of Set 15 | wukari
# Processing Record 31 of Set 15 | tezu
# Processing Record 32 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 33 of Set 15 | kupang
# Processing Record 34 of Set 15 | harper
# Processing Record 35 of Set 15 | vila
# Processing Record 36 of Set 15 | krasnoselkup
# Processing Record 37 of Set 15 | san isidro
# Processing Record 38 of Set 15 | jacareacanga
# Processing Record 39 of Set 15 | srednekolymsk
# Processing Record 40 of Set 15 | rawson
# Processing Record 41 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 15 | rudkobing
# Processing Record 43 of Set 15 | almaznyy
# Processing Record 44 of Set 15 | marrakesh
# Processing Record 45 of Set 15 | shanghai
# Processing Record 46 of Set 15 | rabo de peixe
# Processing Record 47 of Set 15 | yuci
# Processing Record 48 of Set 15 | esso
# Processing Record 49 of Set 15 | baturaja
# Processing Record 50 of Set 15 | ucluelet
# Processing Record 1 of Set 16 | manono
# Processing Record 2 of Set 16 | cascais
# Processing Record 3 of Set 16 | darnah
# Processing Record 4 of Set 16 | bay roberts
# Processing Record 5 of Set 16 | dzhebariki-khaya
# Processing Record 6 of Set 16 | kirensk
# Processing Record 7 of Set 16 | dhidhdhoo
# Processing Record 8 of Set 16 | hsinchu
# Processing Record 9 of Set 16 | ijaki
# City not found. Skipping...
# Processing Record 10 of Set 16 | itaberai
# Processing Record 11 of Set 16 | snezhnogorsk
# Processing Record 12 of Set 16 | oktyabrskoye
# Processing Record 13 of Set 16 | victoria point
# Processing Record 14 of Set 16 | charters towers
# Processing Record 15 of Set 16 | sola
# Processing Record 16 of Set 16 | dukuhturi
# Processing Record 17 of Set 16 | arcachon
# Processing Record 18 of Set 16 | cartagena
# Processing Record 19 of Set 16 | pudozh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 707

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Sao Filipe  14.8961  -24.4956    299.54        57          79        6.51
# 1        Rocha -34.4833  -54.3333    285.47        90           0        2.12
# 2      Mataura -46.1927  168.8643    288.97        32          26        4.08
# 3       Bethel  41.3712  -73.4140    280.64        61           1        0.45
# 4      Rikitea -23.1203 -134.9692    296.24        85          42        4.94
# 5    Busselton -33.6500  115.3333    296.89        47          59        2.59
# 6       Lodwar   3.1191   35.5973    300.67        56          90        7.27
# 7     Kirakira -10.4544  161.9205    303.51        67         100        4.08
# 8   Wilmington  34.2257  -77.9447    287.10        81          79        2.18
# 9  Port Alfred -33.5906   26.8910    290.47        95           4        4.20
#
#   Country       Description
# 0      CV     broken clouds
# 1      UY         clear sky
# 2      NZ  scattered clouds
# 3      US         clear sky
# 4      PF        light rain
# 5      AU     broken clouds
# 6      KE   overcast clouds
# 7      SB   overcast clouds
# 8      US     broken clouds
# 9      ZA         clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Sao Filipe      CV  14.8961  -24.4956    299.54        57          79
# 1        Rocha      UY -34.4833  -54.3333    285.47        90           0
# 2      Mataura      NZ -46.1927  168.8643    288.97        32          26
# 3       Bethel      US  41.3712  -73.4140    280.64        61           1
# 4      Rikitea      PF -23.1203 -134.9692    296.24        85          42
# 5    Busselton      AU -33.6500  115.3333    296.89        47          59
# 6       Lodwar      KE   3.1191   35.5973    300.67        56          90
# 7     Kirakira      SB -10.4544  161.9205    303.51        67         100
# 8   Wilmington      US  34.2257  -77.9447    287.10        81          79
# 9  Port Alfred      ZA -33.5906   26.8910    290.47        95           4
#
#    Wind Speed       Description
# 0        6.51     broken clouds
# 1        2.12         clear sky
# 2        4.08  scattered clouds
# 3        0.45         clear sky
# 4        4.94        light rain
# 5        2.59     broken clouds
# 6        7.27   overcast clouds
# 7        4.08   overcast clouds
# 8        2.18     broken clouds
# 9        4.20         clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
